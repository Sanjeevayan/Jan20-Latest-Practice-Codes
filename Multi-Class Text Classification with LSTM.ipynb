# %%
path= "/Users/kumarsanjeev/Downloads/consumer_complaints.csv"

# %%
import pandas as pd
df=pd.read_csv(path)
# Out:
# /Users/kumarsanjeev/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(200)
# Out:
#     date_received                                            product  \
# 0      08/30/2013                                           Mortgage
# 1      08/30/2013                                           Mortgage
# 2      08/30/2013  Credit reporting, credit repair services, or o...
# 3      08/30/2013                                       Student loan
# 4      08/30/2013                                    Debt collection
# ..            ...                                                ...
# 195    08/30/2013  Credit reporting, credit repair services, or o...
# 196    08/30/2013                                           Mortgage
# 197    09/10/2013                                        Credit card
# 198    09/17/2013                                           Mortgage
# 199    09/17/2013                                        Credit card
#
#                   sub_product                                     issue  \
# ...

# %%
nor_obs1 = df.loc[df.sub_product=="Credit card"]

# %%
nor_obs1
# Out:
#        date_received          product  sub_product  \
# 4         08/30/2013  Debt collection  Credit card
# 14        09/10/2013  Debt collection  Credit card
# 16        09/17/2013  Debt collection  Credit card
# 23        09/10/2013  Debt collection  Credit card
# 63        09/10/2013  Debt collection  Credit card
# ...              ...              ...          ...
# 555847    06/26/2014  Debt collection  Credit card
# 555850    01/15/2015  Debt collection  Credit card
# 555915    08/02/2013  Debt collection  Credit card
# 555943    04/13/2015  Debt collection  Credit card
# 555950    01/21/2014  Debt collection  Credit card
#
#                                         issue  \
# 4          False statements or representation
# 14                      Communication tactics
# 16                      Communication tactics
# 23                      Communication tactics
# 63            Disclosure verification of debt
# ...                                       ...
# ...

# %%
df.sub_product.value_counts()
# Out:
# Other mortgage                            74319
# Conventional fixed mortgage               57182
# Checking account                          44369
# Other (i.e. phone, health club, etc.)     29617
# I do not know                             21634
# Conventional adjustable mortgage (ARM)    20941
# Credit card                               20825
# FHA mortgage                              19152
# Non-federal student loan                  17969
# Medical                                   13297
# Vehicle loan                              12168
# Other bank product/service                10895
# Payday loan                                9684
# Home equity loan or line of credit         8944
# Installment loan                           5279
# Savings account                            3996
# VA mortgage                                3735
# Mortgage                                   3433
# (CD) Certificate of deposit                2839
# Auto                                       2523
# ...

# %%
df.loc[df['product'] == 'Credit reporting', 'product'] = 'Credit reporting, credit repair services, or other personal consumer reports'

# %%
df.loc[df['product'] == 'Credit card', 'product'] = 'Credit card or prepaid card'

# %%
df.loc[df['product'] == 'Payday loan', 'product'] = 'Payday loan, title loan, or personal loan'

# %%
df.loc[df['product'] == 'Virtual currency', 'product'] = 'Money transfer, virtual currency, or money service'
#df = df[df.product != 'Other financial service']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-0d5b82a0cad7> in <module>()
# ...

# %%
df['product'].value_counts().sort_values(ascending=False)
# Out:
# Mortgage                                                                        186475
# Debt collection                                                                 101052
# Credit reporting, credit repair services, or other personal consumer reports     91854
# Credit card or prepaid card                                                      66468
# Bank account or service                                                          62563
# Consumer Loan                                                                    20990
# Student loan                                                                     15839
# Payday loan, title loan, or personal loan                                         3877
# Money transfers                                                                   3812
# Prepaid card                                                                      2470
# Other financial service                                                            557
# ...

# %%
from attention import AttentionLayer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-40-21847fb92901> in <module>()
# ----> 1 from attention import AttentionLayer
#
# ModuleNotFoundError: No module named 'attention'

# %%
df=pd.read_csv(path)
df.shape
# Out:
# /Users/kumarsanjeev/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (555957, 18)

# %%
df.drop_duplicates(subset=['issue'],inplace=True)

# %%
df.dropna(axis=0,inplace=True)

# %%
df.shape
# Out:
# (0, 19)
